# %%
clc;
clear;
close all;
% Quarters
quarters = [1 2 3 4];
% quarterly RPPI
RPPI_2018 = [147.2966 146.5649 143.09 143.68];
RPPI_2019 = [146.1543 150.9074 151.044 154.2029];
RPPI_2020 = [153.5524 160.9517 156.9651 155.7586];
RPPI_2021 = [153.6671 158.4439 158.3397 159.9433];
RPPI_2022 = [162.2014 164.7229 169.3081 167.4026];
RPPI_2023 = [164.9183 171.6491 172.5017 165.6145];
RPPI_2024 = [171.4876 178.4146 179.8116 177.2592];
RPPI_2025 = [180.4258 189.3172 180.6855 NaN]; % Q4 missing
figure
plot(quarters, RPPI_2018,'-o','LineWidth',2)
hold on
plot(quarters, RPPI_2019,'-o','LineWidth',2)
plot(quarters, RPPI_2020,'-o','LineWidth',2)
plot(quarters, RPPI_2021,'-o','LineWidth',2)
plot(quarters, RPPI_2022,'-o','LineWidth',2)
plot(quarters, RPPI_2023,'-o','LineWidth',2)
plot(quarters, RPPI_2024,'-o','LineWidth',2)
plot(quarters, RPPI_2025,'-o','LineWidth',3,'Color','red')
grid on
xticks([1 2 3 4])
xticklabels({'Q1','Q2','Q3','Q4'})
xlabel('Quarter')
ylabel('RPPI Value')
title('Quarterly RPPI Trends for Makati City (2018–2025)')
legend('2018','2019','2020','2021','2022','2023','2024','2025','Location','best')
